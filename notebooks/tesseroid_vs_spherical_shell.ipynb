# %%
# %matplotlib inline

# %%
from IPython.parallel import Client
client = Client()
dview = client[:]
client.ids
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
with dview.sync_imports():
    from StringIO import StringIO
    import pandas
    import json
    import numpy
    from fatiando.constants import MEAN_EARTH_RADIUS, G, SI2EOTVOS, SI2MGAL
    from fatiando.mesher import Tesseroid

# %%
import pandas
import numpy
from fatiando.mesher import Tesseroid
from fatiando.vis import myv
from fatiando.constants import MEAN_EARTH_RADIUS, G, SI2EOTVOS, SI2MGAL
from IPython.display import Image
from matplotlib import pyplot as plt
plt.rcParams['font.size'] = 8

# %% [markdown]
# **note**: Uses package [Fatiando a Terra](http://fatiando.org) for some of the calculations.
# Comparisons are made for both
# the [Tesseroids](http://leouieda.github.com/tesseroids) software
# and the [Fatiando a Terra](https://github.com/leouieda/fatiando) implementation.

# %% [markdown]
# # Forward modeling with adaptive discretization

# %%
def adaptive_discretize(tesseroid, point, ratio):
    lon, lat, h = point
    d2r = numpy.pi/180.    
    radius = h + MEAN_EARTH_RADIUS
    mesh = []
    queue = [tesseroid]
    while queue:
        tesseroid = queue.pop()
        tes_radius = tesseroid.top + MEAN_EARTH_RADIUS
        tes_lat = d2r*0.5*(tesseroid.s + tesseroid.n)
        tes_lon = d2r*0.5*(tesseroid.w + tesseroid.e)
        distance = numpy.sqrt(
            radius**2 + tes_radius**2 - 2.*radius*tes_radius*(
                numpy.sin(d2r*lat)*numpy.sin(tes_lat) 
                + numpy.cos(d2r*lat)*numpy.cos(tes_lat)*numpy.cos(d2r*lon - tes_lon))
            )
        sizes = [MEAN_EARTH_RADIUS*d2r*(tesseroid.e - tesseroid.w),
                 MEAN_EARTH_RADIUS*d2r*(tesseroid.n - tesseroid.s),
                 tesseroid.top - tesseroid.bottom]
        splits = [2 if distance < ratio*size else 1 for size in sizes]
        if 2 in splits:
            queue.extend(tesseroid.half())
        else:
            mesh.append(tesseroid)
    return mesh

# %%
sampletess = Tesseroid(-55, -25, -80, -70, 500000, 0)
point = [-40, -70, 800000]

# %%
def setview(scene):
    scene.scene.camera.position = [16416679.707178073, -37375463.056315556, -8217239.6229258822]
    scene.scene.camera.focal_point = [17524.775500096133, 2455801.3439532616, -6133960.4172555953]
    scene.scene.camera.view_angle = 2.0615843020800004
    scene.scene.camera.view_up = [-0.010129246170078175, 0.048069096295061252, -0.99879265133129702]
    scene.scene.camera.clipping_range = [23552679.71500038, 63396872.424586065]
    scene.scene.camera.compute_view_plane_normal()
    scene.scene.render()

# %%
scene = myv.figure(zdown=False, size=(800, 600))
myv.earth(opacity=1, color=(0.7, 0.7, 0.7))
myv.continents(linewidth=2)
# Split the tesseroid so that it doesn't look so square in the plot
myv.tesseroids(sampletess.split(35, 35, 20), edges=False, color=(0.4, 0.4, 0.4))
myv.points([point], size=30000, spherical=True)
myv.meridians(range(0, 360, 30))
myv.parallels(range(-90, 0, 15))
setview(scene)
myv.savefig('tesseroid-whole.png')
myv.show()

# %%
Image(filename='tesseroid-whole.png')

# %%
for split in [0.5, 1, 2]:
    scene = myv.figure(zdown=False, size=(800, 600))
    myv.earth(opacity=1, color=(0.7, 0.7, 0.7))
    myv.continents(linewidth=2)
    model = adaptive_discretize(sampletess, point, split)
    print "Number of tesseroids:", len(model)
    myv.tesseroids(model, linewidth=2, edges=True, color=(0.4, 0.4, 0.4))
    myv.points([point], size=30000, spherical=True)
    myv.meridians(range(0, 360, 30))
    myv.parallels(range(-90, 0, 15))
    setview(scene)
    myv.savefig('tesseroid-split%g.png' % (split))
myv.show()
# Out:
# Number of tesseroids: 50
# Number of tesseroids:
#  344
# Number of tesseroids:
#  2472

# %%
Image(filename='tesseroid-split0.5.png')

# %%
Image(filename='tesseroid-split1.png')

# %%
Image(filename='tesseroid-split2.png')

# %% [markdown]
# # Tesseroid versus spherical shell
#
# We want to analyse the error involed in calculating the gravitational potential and its derivatives using tesseroids.
# The fields are calculated using a Gauss-Legendre Quadrature (GLQ) integration.
# Ku (1977) showed that the error of the GLQ for rectangular prisms depends on the ratio of the distance between GLQ discretization points (nodes) and the distance between the prism and the observation point.

# %% [markdown]
# ## Tesseroid models
#
# We will need to make tesseroid models of half a spherical shell for varying tesseroid sizes.
# The shell thickness is set to 50 km to represent a crustal model.

# %%
def make_model(size, thickness, density):
    # Stream the model to avoid overloading the memory
    for w in numpy.arange(0, 180, size):
        for s in numpy.arange(-90, 90, size):
            yield Tesseroid(w, w+size, s, s+size, 0, -thickness, {'density':density})

def dump_model(model, fname):
    with open(fname, 'w') as f:
        for t in model:
            f.write('%.10f %.10f %.10f %.10f %.10f %.10f %.10f\n'
                    % (t.w, t.e, t.s, t.n, t.top, t.bottom, t.props['density']))
    return fname

# %% [markdown]
# ## Spherical shell
#
# First, we need to calculate the effect of a spherical shell.
#
# We'll use only half of a full spherical shell to speed up the computations.
#
# The analytical solution exists for an observation point located on the pole.
# Since we're using half a shell, we slice it at the 0 longitude meridian (going through the poles) and pretend that the point is actually on the equator.
# This way, we avoid the numerical singularities of tesseroids in the pole.

# %%
scene = myv.figure(size=(800, 800), zdown=False)
# The thickness is exagerated for better viewing
surf = myv.tesseroids(make_model(10, thickness=1000000, density=1), edges=True, linewidth=2)
surf.actor.mapper.scalar_visibility = False
surf.actor.property.color = (0.7, 0.7, 0.7)
#myv.tesseroids([Tesseroid(0, 10, -15, -5, 10000, -1000000),
#                Tesseroid(0, 10, -5, 5, 10000, -1000000),
#                Tesseroid(0, 10, 5, 15, 10000, -1000000)], 
#               style='wireframe', color=(0, 0, 0), linewidth=5)
myv.points([[90, 0, 2500000]], size=200000, spherical=True)
myv.earth(opacity=0.2, color=(0.4, 0.4, 0.4))
myv.continents(linewidth=2)
#myv.meridians(range(0, 360, 45))
#myv.parallels(range(-90, 90, 45))
# Set the view (used the record function in Mayavi to generate the code)
scene.scene.camera.position = [28113182.448563591, -5689344.429264321, 2878096.6411631284]
scene.scene.camera.focal_point = [-27617.931075808912, 1264951.5547663779, -222144.30788129801]
scene.scene.camera.view_angle = 30.0
scene.scene.camera.view_up = [-0.10247927744297783, 0.028586078863405598, 0.9943243101674526]
scene.scene.camera.clipping_range = [11573617.460230589, 51256146.126885667]
scene.scene.camera.compute_view_plane_normal()
scene.scene.render()
myv.savefig('spherical-shell.png')
myv.show()

# %%
Image(filename='spherical-shell.png')

# %% [markdown]
# The potential of such a shell is:
#
# $V(r) = 2\pi G \rho \left[ \dfrac{l^3 + {r'}^3}{3r} - 0.5 {r'}^2 \right] \Biggr\rvert_{r'=r_1}^{r'=r_2} $
#
# where $\rho$ is the dentity, $l = \sqrt{r^2 + {r'}^2}$, $r$ is the radius coordinate of the observation point, $r_1$ and $r_2$ are the bottom and top of the spherical shell, respectively.

# %% [markdown]
# The $g_z$ component of the gravitational attraction for this shell is the radial derivative of the potential.
#
# The sign should be inverted because our convention is that z points down (toward the center of the Earth)
#
# $g_z(r) = -\dfrac{\partial V}{\partial r} = 2\pi G \rho \left[ \dfrac{l^3 + {r'}^3}{3r^2} - l \right] \Biggr\rvert_{r'=r_1}^{r'=r_2}$

# %% [markdown]
# The gravity gradient tensor are the second derivatives of $V$:
#
# $g_{xx}(r) = -\dfrac{1}{2} g_{zz}$
#
# $g_{xy}(r) = 0$
#
# $g_{xz}(r) = 0$
#
# $g_{yy}(r) = -\dfrac{1}{2} g_{zz}$
#
# $g_{yz}(r) = 0$
#
# $g_{zz}(r) = 2\pi G \rho \left[ 2\dfrac{l^3 + {r'}^3}{3r^3} - \dfrac{l}{r} + \dfrac{r}{l} \right] \Biggr\rvert_{r'=r_1}^{r'=r_2}$

# %% [markdown]
# ## Comparison with Tesseroids

# %% [markdown]
# Create the tesseroid models and compare the results obtained using Tesseroids for various distance/size ratios.
#
# The results will be saved to a CSV file.

# %%
print "Mean Earth radius = ", MEAN_EARTH_RADIUS, "m"
thickness = 50000
density = 2700
fields = ['pot', 'gz', 'gxx', 'gxy', 'gxz', 'gyy', 'gyz', 'gzz']

ratios = range(9)
heights = numpy.array([1, 100, 1000, 10000, 100000, 250000, 500000])
sizes = [0.1, 1, 5, 10, 20]

#sizes = [10, 20]
#heights = numpy.array([250000, 500000])
# Out:
# Mean Earth radius =  6378137.0 m

# %%
lons = 90*numpy.ones_like(heights)
lats = numpy.zeros_like(heights)
numpy.savetxt('points.txt', numpy.transpose([lons, lats, heights]), fmt='%.1f')
# !cat points.txt
# Out:
# 90.0 0.0 1.0
# 90.0 0.0 100.0
# 90.0 0.0 1000.0
# 90.0 0.0 10000.0
# 90.0 0.0 100000.0
# 90.0 0.0 250000.0
# 90.0 0.0 500000.0

# %%
model_files = [dump_model(make_model(size, thickness, density), 'model%g.txt' % size) 
               for size in sizes]
model_files
# Out:
# ['model0.1.txt', 'model1.txt', 'model5.txt', 'model10.txt', 'model20.txt']

# %%
data = pandas.read_csv('tesseroid_vs_spherical_shell.csv')

# %%
dview.push(dict(
    ratios=ratios, 
    heights=heights, 
    thickness=thickness, 
    density=density, 
    sizes=sizes,
    model_files=model_files,
    dump_model=dump_model, 
    make_model=make_model))
dview.scatter('fields', fields)
# Out:
# <AsyncResult: scatter>

# %%
# %%px
# dummy = lambda heights, a, b, c: numpy.zeros_like(heights)
# shellfuncs = dict(
#     pot=half_sph_shell.potential,
#     gz=half_sph_shell.gz,
#     gxx=half_sph_shell.gxx,
#     gxy=dummy,
#     gxz=dummy,
#     gyy=half_sph_shell.gyy,
#     gyz=dummy,
#     gzz=half_sph_shell.gzz)
# nheights = len(heights)
# data = pandas.DataFrame({}, columns=[
#     'field',
#     'size',
#     'ratio',
#     'height',
#     'tesseroid',
#     'shell',
#     'difference'])
# for fname, size in zip(model_files, sizes):
#     for ratio in ratios:
#         # Assemble the pipeline
#         if ratio == 0:
#             flag = '-a'
#         else:
#             flag = '-t%g' % (ratio)
#         for field in fields:
#             pipeline = ' | '.join(['cat points.txt', 'tess%s %s %s' % (field, fname, flag)])
#             # Catch the output in tmp
#             tmp = !$pipeline
#             # and load it to a numpy array. Discard the lon, lat, height columns
#             tessvalue = numpy.loadtxt(StringIO('\n'.join(tmp)), unpack=True, usecols=[3])
#             shellvalue = shellfuncs[field](heights, 0, -thickness, density)
#             diff = tessvalue - shellvalue
#             data = data.append(
#                 pandas.DataFrame(
#                     {'field': field,
#                      'size': size,
#                      'ratio': ratio,
#                      'height': heights,
#                      'tesseroid': tessvalue,
#                      'shell': shellvalue,
#                      'difference': diff,
#                     }))

# %%
data = pandas.concat(dview.gather('data').get(), ignore_index=True)
data.sort('field', inplace=True)

# %%
data.to_csv('tesseroid_vs_spherical_shell.csv', index=False)
data.to_pickle('tesseroid_vs_spherical_shell.pickle')

# %%
data[data.field == 'gz'][data.height == 100][data.size == 1].sort('ratio')
# Out:
# /home/leo/bin/anaconda/lib/python2.7/site-packages/pandas/core/frame.py:1663: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   "DataFrame index.", UserWarning)
#       difference field  height  ratio       shell  size    tesseroid
# 1639 -822.411972    gz     100      0  9578.95781     1  8756.545838
# 1646   -6.179354    gz     100      1  9578.95781     1  9572.778455
# 1653   -0.469291    gz     100      2  9578.95781     1  9578.488519
# 1660   -0.159858    gz     100      3  9578.95781     1  9578.797952
# 1667   -0.063757    gz     100      4  9578.95781     1  9578.894053
# 1674   -0.029417    gz     100      5  9578.95781     1  9578.928392
# 1681   -0.015198    gz     100      6  9578.95781     1  9578.942612
# 1688   -0.008178    gz     100      7  9578.95781     1  9578.949631
# 1695   -0.004805    gz     100      8  9578.95781     1  9578.953005
#
# [9 rows x 7 columns]

# %%
titles = dict(zip(fields, 
    ['$V$', r'$g_{z}$', r'$g_{xx}$', r'$g_{yy}$', r'$g_{zz}$', r'$g_{xy}$', r'$g_{xz}$', r'$g_{yz}$']))
maxerror = 1 # percent
estimated_ratio = dict(pot=0.5, gz=1, gxx=2, gxy=2, gxz=2, gyy=2, gyz=2, gzz=2)

# %%
def plot(data, field, size):
    df = data[data.field == field][data.size == size]
    for height in heights:
        x = df[data.height == height].ratio
        y = numpy.abs(df[data.height == height].difference)
        if field not in ['gxy', 'gxz', 'gyz']:
            y /= numpy.abs(df[data.height == height].shell)
            y *= 100.
        plt.plot(x, y, '-', label='%g' % (0.001*height))        
    ax = plt.gca()
    ax.set_yscale('log') 
    plt.vlines([estimated_ratio[field]], ax.get_ybound()[0], ax.get_ybound()[1], 'k', '--', linewidth=2)
    plt.hlines([maxerror], x.min(), x.max(), 'r', '--')
    plt.xlim(x.min(), x.max())
    plt.grid()

# %%
def plot_per_size(data, size):
    fields = ['pot', 'gz', 'gxx', 'gyy', 'gzz']
    plt.figure(figsize=(4.33, 6.5))
    plt.subplots_adjust(top=0.95, right=0.98, bottom=0.05, wspace=0.25, hspace=0.25)
    for i, field in enumerate(fields):
        plt.subplot(3, 2, i + 1)
        plt.title(titles[field], fontsize=14)
        plot(data, field, size)
        if i + 1 in [1, 3, 5]:
            plt.ylabel(r'Error (%)')    
        if i + 1 in [4, 5]:
            plt.xlabel('Distance/size')
    plt.legend(title='Height (km)', 
               shadow=True, 
               fancybox=True, 
               ncol=1, 
               prop={'size':8}, 
               loc=(1.52, 0.05))

# %%
plot_per_size(data, 20)
plt.savefig('error-20deg.eps')

# %%
plot_per_size(data, 1)
plt.savefig('error-1deg.eps')

# %%
plot_per_size(data, 5)
plt.savefig('error-5deg.eps')

# %%
plot_per_size(data, 10)
plt.savefig('error-10deg.eps')

# %% [markdown]
# # References
#
# Ku, C. C. (1977), A direct computation of gravity and magnetic anomalies caused by 2-and 3-dimensional bodies of arbitrary shape and arbitrary magnetic polarization by equivalent-point method and a simplified cubic spline, Geophysics, 42(3), 610–622, doi:10.1190/1.1440732.
