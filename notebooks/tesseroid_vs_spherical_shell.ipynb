# %% [markdown]
# # A comparison of the effects of tesseroids against a spherical shell
#
# This notebook compares the gravitational fields calculated for a tesseroid model against the analytical solution for a spherical shell.
#
# The tesseroid fields are calculated using a range of distance/size ratios for the recursive division of the tesseroids. The sphell fields are used as a reference, or "ground truth". We use the difference between the tesseroid and reference fields to quantify the error in the tesseroid calculations for each distance/size ratio.

# %% [markdown]
# ## Provenance information
#
# Load libraries and print the version information.

# %%
# %matplotlib inline
from __future__ import division
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import rc_file
rc_file('matplotlibrc')
from fatiando.gravmag import tesseroid
from fatiando.mesher import Tesseroid, TesseroidMesh
from fatiando.constants import MEAN_EARTH_RADIUS, G, SI2EOTVOS, SI2MGAL
from fatiando import gridder
import fatiando

# %%
print('Fatiando a Terra version: {}\n'.format(fatiando.__version__))
# Out:
# Fatiando a Terra version: 0.2-187-g71f2e50

# %%
# !tessgz --version
# Out:
# tessgz (Tesseroids project) 1.1.1-56-gd510906
#
# Copyright (C) 2011-2014, Leonardo Uieda.
# This software is distributed under the terms of the BSD License:
# <http://tesseroids.readthedocs.org/en/latest/license.html>
# This is free software: you are free to change and redistribute it.
# There is NO WARRANTY, to the extent permitted by law.
#
# Developed by Leonardo Uieda.

# %% [markdown]
# ## Make the directory where the files will go

# %%
filedir = 'tesseroid_vs_spherical_shell_files'
# !mkdir -p $filedir

# %% [markdown]
# ## Gravitational effect of a spherical shell

# %% [markdown]
# The analytical solution exists for an observation point located at a geocentric radial coordinate $r$. We can pretend that the point is at any latitude and longitude because of the symmetry of the shell.

# %% [markdown]
# The potential and its first and second derivatives are given by (Grombein et al., 2013):
#
# $$
# V(r) = \dfrac{4}{3}\pi G \rho \dfrac{r_2^3 - r_1^3}{r},
# $$
#
# $$
# g_z(r) = \dfrac{V(r)}{r},
# $$
#
# $$
# g_{zz}(r) = 2\dfrac{V(r)}{r^2},
# $$
#
# $$
# g_{xx}(r) = g_{yy}(r) = -\dfrac{g_{zz}}{2} = -\dfrac{V(r)}{r^2},,
# $$
#
#
# and (because of the symmetry of the shell)
#
# $$
# g_x(r) = g_y(r) = g_{xy}(r) = g_{xz}(r) = g_{yz}(r) = 0,
# $$
#
#
# where $\rho$ is the dentity, $r$ is the radius coordinate of the observation point, $r_1$ and $r_2$ are radial coordinates of the bottom and top of the spherical shell, respectively.

# %% [markdown]
# The function below calculates the shell fields and returns them in a `pandas.Series`.

# %%
def calc_shell_effect(height, top, bottom, density):
    r = height + MEAN_EARTH_RADIUS
    # top and bottom are heights
    r1 = bottom + MEAN_EARTH_RADIUS
    r2 = top + MEAN_EARTH_RADIUS
    potential = (4/3)*np.pi*G*density*(r2**3 - r1**3)/r
    data = pd.Series({'pot': potential,
                      'gx': 0,
                      'gy': 0,
                      'gz': SI2MGAL*(potential/r),
                      'gxx': SI2EOTVOS*(-potential/r**2),
                      'gxy': 0,
                      'gxz': 0,
                      'gyy': SI2EOTVOS*(-potential/r**2),
                      'gyz': 0,
                      'gzz': SI2EOTVOS*(2*potential/r**2)})
    return data

# %% [markdown]
# ## Tesseroid model of the spherical shell

# %% [markdown]
# I'll use the `TesseroidMesh` of Fatiando a Terra to make a model of a spherical shell. The model needs to be written to a file so that I can use the [Tesseroids](http://www.leouieda.com/tesseroids) command-line programs on it.
#
# The function below takes the size (in degrees), top, bottom and density, makes the tesseroids and saves them to a file.

# %%
def make_model_file(size, top, bottom, density, verbose=False, return_mesh=False):
    bounds = [0, 360, -90, 90, top, bottom]
    nlon = int(360/size)
    assert nlon - 360/size == 0
    nlat = int(180/size)
    assert nlat - 180/size == 0
    mesh = TesseroidMesh(bounds, (1, nlat, nlon))
    # the 3rd dim is - because of a quirk in TesseroidMesh
    assert mesh.dims == (size, size, -(top - bottom))
    assert mesh.size == nlat*nlon
    fname = os.path.join(filedir, 'model-size{:g}.tess'.format(size))
    with open(fname, 'w') as f:
        for t in mesh:
            f.write('{} {} {} {} {} {} {}\n'.format(
                t.w, t.e, t.s, t.n, t.top, t.bottom, density))
    tmp = !cat $fname | grep -v "#" | grep -e "^$" -v| wc -l
    tess_in_file = int(tmp[0])
    assert mesh.size == tess_in_file
    if verbose:
        print('Model file: {}'.format(fname))
        print('Model size: {}'.format(tess_in_file))
        print('Head:')
        # !head $fname
        print('Tail:')
        # !tail $fname
    if return_mesh:
        return fname, mesh
    else:
        return fname

# %% [markdown]
# We'll make a 30x30 degree tesseroid model so that it doesn't take too long to calculate and we can test things. Later on, we'll run the computations on finner models.

# %%
size = 30
top, bottom = 1000, 0
density = 2670

# %%
model_file, mesh = make_model_file(size, top, bottom, density, verbose=True, return_mesh=True)
# Out:
# Model file: tesseroid_vs_spherical_shell_files/model-size30.tess
# Model size: 72
# Head:
# 0.0 30.0 -90.0 -60.0 1000.0 0.0 2670
# 30.0 60.0 -90.0 -60.0 1000.0 0.0 2670
# 60.0 90.0 -90.0 -60.0 1000.0 0.0 2670
# 90.0 120.0 -90.0 -60.0 1000.0 0.0 2670
# 120.0 150.0 -90.0 -60.0 1000.0 0.0 2670
# 150.0 180.0 -90.0 -60.0 1000.0 0.0 2670
# 180.0 210.0 -90.0 -60.0 1000.0 0.0 2670
# 210.0 240.0 -90.0 -60.0 1000.0 0.0 2670
# 240.0 270.0 -90.0 -60.0 1000.0 0.0 2670
# 270.0 300.0 -90.0 -60.0 1000.0 0.0 2670
# Tail:
# 60.0 90.0 60.0 90.0 1000.0 0.0 2670
# 90.0 120.0 60.0 90.0 1000.0 0.0 2670
# 120.0 150.0 60.0 90.0 1000.0 0.0 2670
# 150.0 180.0 60.0 90.0 1000.0 0.0 2670
# 180.0 210.0 60.0 90.0 1000.0 0.0 2670
# 210.0 240.0 60.0 90.0 1000.0 0.0 2670
# 240.0 270.0 60.0 90.0 1000.0 0.0 2670
# 270.0 300.0 60.0 90.0 1000.0 0.0 2670
# 300.0 330.0 60.0 90.0 1000.0 0.0 2670
# 330.0 360.0 60.0 90.0 1000.0 0.0 2670

# %% [markdown]
# Now we need to calculate the gravitational effect of this tesseroid model using a range of distance/size ratios. The function below takes a model file name,  height of observations, tesseroid size, and a distance to size ratio. It makes a computation grid at the given height. The grid is placed over the North pole from 90º latitude until 90º - the size of the tesseroids. This way, he grid covers all the tesseroids that are around the pole.

# %%
def calc_tess_effect(fname, height, size, ratio):
    if ratio == 0:
        flag = '-a'
    else:
        flag = '-t{:f}'.format(ratio)
    tmp = 'effect-{}-ratio{:f}.txt'.format(os.path.split(fname)[1], ratio)
    outfile = os.path.join(filedir, tmp)
    # Make a computation grid above the tesseroid with corner at 0, 0
    lats, lons = gridder.regular([90 - size, 90, 0, size], (21, 21))
    grid_text = '\n'.join('{:f} {:f} {:f}'.format(lon, lat, height) 
                          for lon, lat in zip(lons, lats))
    # !echo "$grid_text" | \
        tesspot $fname $flag | \
        tessgx $fname $flag | \
        tessgy $fname $flag | \
        tessgz $fname $flag | \
        tessgxx $fname $flag | \
        tessgxy $fname $flag | \
        tessgxz $fname $flag | \
        tessgyy $fname $flag | \
        tessgyz $fname $flag | \
        tessgzz $fname $flag > $outfile
    return outfile

# %% [markdown]
# Now we can specify a range of distance/size ratios and a computation height...

# %%
ratio = np.arange(0, 8.5, 0.5)
height = top + 1000

# %% [markdown]
# ... and calculate the effect of the tesseroid model for each ratio.

# %%
tess_out_files = [calc_tess_effect(model_file, height, size, r) for r in ratio]

# %% [markdown]
# These are the output files generated:

# %%
tess_out_files
# Out:
# ['tesseroid_vs_spherical_shell_files/effect-model-size30.tess-ratio0.000000.txt',
#  'tesseroid_vs_spherical_shell_files/effect-model-size30.tess-ratio0.500000.txt',
#  'tesseroid_vs_spherical_shell_files/effect-model-size30.tess-ratio1.000000.txt',
#  'tesseroid_vs_spherical_shell_files/effect-model-size30.tess-ratio1.500000.txt',
#  'tesseroid_vs_spherical_shell_files/effect-model-size30.tess-ratio2.000000.txt',
#  'tesseroid_vs_spherical_shell_files/effect-model-size30.tess-ratio2.500000.txt',
#  'tesseroid_vs_spherical_shell_files/effect-model-size30.tess-ratio3.000000.txt',
#  'tesseroid_vs_spherical_shell_files/effect-model-size30.tess-ratio3.500000.txt',
#  'tesseroid_vs_spherical_shell_files/effect-model-size30.tess-ratio4.000000.txt',
#  'tesseroid_vs_spherical_shell_files/effect-model-size30.tess-ratio4.500000.txt',
#  'tesseroid_vs_spherical_shell_files/effect-model-size30.tess-ratio5.000000.txt',
#  'tesseroid_vs_spherical_shell_files/effect-model-size30.tess-ratio5.500000.txt',
#  'tesseroid_vs_spherical_shell_files/effect-model-size30.tess-ratio6.000000.txt',
#  'tesseroid_vs_spherical_shell_files/effect-model-size30.tess-ratio6.500000.txt',
#  'tesseroid_vs_spherical_shell_files/effect-model-size30.tess-ratio7.000000.txt',
#  'tesseroid_vs_spherical_shell_files/effect-model-size30.tess-ratio7.500000.txt',
#  'tesseroid_vs_spherical_shell_files/effect-model-size30.tess-ratio8.000000.txt']

# %% [markdown]
# ## Comparison of spherical shell effect and tesseroid model

# %% [markdown]
# Now I can load the calculated fields of the tesseroid model and compare it with the calculated effect for the real spherical shell.

# %%
shell_data = calc_shell_effect(height, top, bottom, density)
shell_data
# Out:
# gx         0.000000
# gxx       -0.350758
# gxy        0.000000
# gxz        0.000000
# gy         0.000000
# gyy       -0.350758
# gyz        0.000000
# gz       223.788630
# gzz        0.701517
# pot    14278.021191
# dtype: float64

# %% [markdown]
# I'll load the tesseroid data into a `pandas.DataFrame` object. This is a like a spreadsheet, but better. The columns are the fields (gx, gy, etc), file name, ratio used, and tesseroid size.

# %%
def load_tess_data(files, ratio, size):
    df = pd.DataFrame(columns=['file', 'ratio', 'size', 'gx', 'gxx', 'gxy', 'gxz', 'gy', 
                               'gyy', 'gyz', 'gz', 'gzz', 'pot'])
    for r, fname in zip(ratio, files):
        data = np.loadtxt(fname, usecols=range(3, 13), unpack=True)
        tmp = pd.DataFrame({'file': fname,
                            'ratio': r,
                            'size': size,
                            'pot': data[0],
                            'gx': data[1],
                            'gy': data[2],
                            'gz': data[3],
                            'gxx': data[4],
                            'gxy': data[5],
                            'gxz': data[6],
                            'gyy': data[7],
                            'gyz': data[8],
                            'gzz': data[9]})
        df = df.append(tmp, ignore_index=True)
    df.index.name = 'point'
    return df

# %% [markdown]
# Lets take a look at the 30 degree tesseroid data:

# %%
tess_data = load_tess_data(tess_out_files, ratio, size)
tess_data.head()
# Out:
#                                                     file          gx  \
# point
# 0      tesseroid_vs_spherical_shell_files/effect-mode...   -5.080438
# 1      tesseroid_vs_spherical_shell_files/effect-mode...   47.187352
# 2      tesseroid_vs_spherical_shell_files/effect-mode...  111.670908
# 3      tesseroid_vs_spherical_shell_files/effect-mode...  172.906610
# 4      tesseroid_vs_spherical_shell_files/effect-mode...   76.225435
#
#              gxx           gxy       gxz            gy        gyy  \
# point
# 0       2.740485 -2.120526e-14  0.012423  1.136868e-13  -0.206607
# 1       3.254847 -5.329071e-15 -0.119124 -2.842171e-13  -0.331153
# 2       4.083376 -2.042810e-14 -0.288925 -4.973799e-13   0.610316
# 3       1.426613 -4.707346e-14 -0.473062 -1.136868e-12   8.238928
# 4     -14.995095 -6.394885e-14 -0.226576 -1.932676e-12  32.672668
#
#                 gyz          gz        gzz           pot  ratio  size
# point
# 0     -4.857226e-16  110.584616  -2.533878  14057.411640      0    30
# 1      6.522560e-16  110.909484  -2.923694  14091.387903      0    30
# 2      1.193490e-15  112.199375  -4.693692  14222.035946      0    30
# 3      2.886580e-15  114.851910  -9.665542  14465.195711      0    30
# 4      5.218048e-15  118.001247 -17.677573  14713.512290      0    30

# %% [markdown]
# Now I can use some pandas magic to calculate the difference between the shell effect and the tesseroid effect. This will also be stored in a `DataFrame`. The values are the absolute value of the differences for each size and ratio.

# %%
def calc_difference(tess_data, shell_data):
    # Subtract the field columns and take the absolute value
    diff = tess_data.drop(['file', 'size', 'ratio'], axis='columns').sub(shell_data, axis='columns').abs()
    # Then, add the size and ratio columns to the difference
    diff[['size', 'ratio']] = tess_data[['size', 'ratio']]
    return diff

# %%
diff = calc_difference(tess_data, shell_data)
diff.head()
# Out:
#                gx        gxx           gxy       gxz            gy        gyy  \
# point
# 0        5.080438   3.091243  2.120526e-14  0.012423  1.136868e-13   0.144152
# 1       47.187352   3.605605  5.329071e-15  0.119124  2.842171e-13   0.019606
# 2      111.670908   4.434134  2.042810e-14  0.288925  4.973799e-13   0.961075
# 3      172.906610   1.777372  4.707346e-14  0.473062  1.136868e-12   8.589687
# 4       76.225435  14.644337  6.394885e-14  0.226576  1.932676e-12  33.023427
#
#                 gyz          gz        gzz         pot  size  ratio
# point
# 0      4.857226e-16  113.204014   3.235395  220.609550    30      0
# 1      6.522560e-16  112.879146   3.625211  186.633288    30      0
# 2      1.193490e-15  111.589255   5.395209   55.985245    30      0
# 3      2.886580e-15  108.936720  10.367058  187.174520    30      0
# 4      5.218048e-15  105.787383  18.379090  435.491100    30      0

# %% [markdown]
# The `DataFrame.describe()` method prints some statistics about the differences.

# %%
diff.describe()
# Out:
#                  gx          gxx          gxy           gxz           gy  \
# count  7.497000e+03  7497.000000  7497.000000  7.497000e+03  7497.000000
# mean   1.579983e+01     4.510560     3.611152  8.862275e-01     7.211847
# std    2.165718e+02    86.149934    58.687317  7.237073e+00   115.591178
# min    1.456613e-13     0.000002     0.000000  3.469447e-16     0.000000
# 25%    7.904816e-05     0.000277     0.000001  9.334464e-05     0.000001
# 50%    4.160197e-04     0.001584     0.000046  3.946421e-04     0.000028
# 75%    1.096937e-02     0.038983     0.003056  9.130901e-03     0.001122
# max    1.109533e+04  4629.793426  3030.511198  3.254881e+02  4412.261681
#
#                 gyy          gyz           gz          gzz          pot  size  \
# count  7.497000e+03  7497.000000  7497.000000  7497.000000  7497.000000  7497
# mean   3.719167e+00     0.841498     9.416834     3.992952    24.774845    30
# std    3.909478e+01     4.783347    30.682303    57.380945   136.488903     0
# min    1.619801e-09     0.000000     0.000068     0.000007     0.000000    30
# 25%    3.159088e-04     0.000001     0.000416     0.000611     0.000118    30
# 50%    2.116605e-03     0.000179     0.002002     0.003351     0.000982    30
# 75%    5.534186e-02     0.003681     0.030090     0.059186     0.025396    30
# max    1.711273e+03   130.389153   361.782832  2918.520834  4328.250458    30
#
#              ratio
# count  7497.000000
# mean      4.000000
# std       2.449653
# min       0.000000
# 25%       2.000000
# 50%       4.000000
# 75%       6.000000
# max       8.000000

# %% [markdown]
# To get the maximum difference per size per ratio, I can use the `DataFrame.groupby` method.

# %%
max_diff = diff.groupby(['size', 'ratio']).max()
max_diff
# Out:
#                       gx          gxx          gxy         gxz           gy  \
# size ratio
# 30   0.0    11095.326880  4629.793426  3030.511198  325.488084  4412.261681
#      0.5      113.615182   203.486129    70.203355   47.062307    81.442870
#      1.0        1.184469    14.740995     3.866946    3.845523     0.698832
#      1.5        0.114923     0.726540     0.380030    0.279439     0.094024
#      2.0        0.042898     0.113413     0.082160    0.068976     0.014692
#      2.5        0.008445     0.042375     0.016112    0.023419     0.004159
#      3.0        0.004803     0.027291     0.004151    0.010204     0.001495
#      3.5        0.001886     0.007556     0.002376    0.004958     0.000771
#      4.0        0.001310     0.007496     0.001781    0.003320     0.000401
#      4.5        0.000619     0.003153     0.000505    0.001104     0.000180
#      5.0        0.000387     0.001604     0.000351    0.001188     0.000124
#      5.5        0.000281     0.001292     0.000306    0.000507     0.000076
#      6.0        0.000210     0.001016     0.000135    0.000542     0.000051
#      6.5        0.000128     0.000558     0.000104    0.000281     0.000036
#      7.0        0.000105     0.000698     0.000066    0.000226     0.000025
#      7.5        0.000090     0.000357     0.000043    0.000195     0.000017
#      8.0        0.000059     0.000279     0.000047    0.000147     0.000016
#
#                     gyy         gyz          gz          gzz          pot
# size ratio
# 30   0.0    1711.272592  130.389153  361.782832  2918.520834  4328.250458
#      0.5     482.170746   45.336597  113.549427   326.943150   260.748575
#      1.0      11.624786    2.182199    0.644165     3.119782     2.389878
#      1.5       0.788297    0.305783    0.281056     0.498055     1.358251
#      2.0       0.167472    0.065274    0.035118     0.154040     0.086626
#      2.5       0.060576    0.012972    0.024220     0.083600     0.078116
#      3.0       0.024478    0.011345    0.007229     0.035686     0.018671
#      3.5       0.012203    0.006435    0.005393     0.011096     0.013664
#      4.0       0.008458    0.003492    0.002325     0.008523     0.004656
#      4.5       0.004097    0.001491    0.001753     0.004336     0.003599
#      5.0       0.002352    0.001180    0.001010     0.003072     0.001668
#      5.5       0.001402    0.000510    0.000784     0.001759     0.001436
#      6.0       0.001017    0.000525    0.000508     0.002032     0.000857
#      6.5       0.000615    0.000300    0.000420     0.001066     0.000668
#      7.0       0.000698    0.000201    0.000299     0.001395     0.000380
#      7.5       0.000357    0.000209    0.000220     0.000714     0.000314
#      8.0       0.000297    0.000139    0.000166     0.000558     0.000182

# %% [markdown]
# I'll plot the maximum difference as a function of distance/size ratio. I'll also plot the relative difference (difference divided by the shell value) in percentage.

# %%
fig, subplots = plt.subplots(3, 2, figsize=(10, 10))
for f, axes in zip(max_diff[['pot', 'gz', 'gzz']], subplots):
    maxd = max_diff[f].loc[30, :] # Get only the difference for size 30 tesseroids
    ax1, ax2 = axes
    ax1.text(0.8, 0.8, f, fontsize=16, transform=ax1.transAxes)
    ax1.plot(ratio, maxd, '.-')
    ax1.set_yscale('log')
    ax1.grid(True)
    ax1.set_ylabel('Difference')
    ax2.plot(ratio, 100*maxd/np.abs(shell_data[f]), '.-')
    ax2.set_yscale('log')
    ax2.grid(True)
    ax2.set_ylabel('Difference (\%)')
    ax2.hlines(0.1, ratio.min(), ratio.max(), colors='r')
    ax2.set_xlim(ratio.min(), ratio.max())
ax1.set_xlabel('Distance/size ratio')
ax2.set_xlabel('Distance/size ratio')
ax1, ax2 = subplots[0]
ax1.set_title('Absolute difference')
ax2.set_title('Realtive difference')
plt.tight_layout()
plt.show()

# %% [markdown]
# I can save the 30 degree data to CSV files for later use. These files can be opened in spreadsheet software, like LibreOffice Calc and Gnumeric.

# %%
tess_data.to_csv(os.path.join(filedir, '30-deg-tesseroid-data.csv'), sep=',')
diff.to_csv(os.path.join(filedir, '30-deg-difference.csv'), sep=',')

# %% [markdown]
# Lets plot the computed gravitational fields to see if the computations are OK.
# For all fields, the values of all points should be the same.

# %%
from cartopy import crs

# %%
grid = gridder.Grid.load(tess_data[(tess_data.ratio == 7.5) & (tess_data.size == 30)].file.unique()[0],
                         column_names='lon lat h pot gx gy gz gxx gxy gxz gyy gyz gzz'.split())
grid.shape = (21, 21)
grid.set_projection(crs.Geodetic())
for att in grid.get_attributes():
    if att == 'h':
        continue
    grid.add_attribute(att + '_diff', 100*np.abs(getattr(grid, att) - shell_data[att])/abs(shell_data[att]))
shell_data
# Out:
# gx         0.000000
# gxx       -0.350758
# gxy        0.000000
# gxz        0.000000
# gy         0.000000
# gyy       -0.350758
# gyz        0.000000
# gz       223.788630
# gzz        0.701517
# pot    14278.021191
# dtype: float64

# %%
fig, axes = plt.subplots(1, 2, subplot_kw=dict(projection=crs.LambertConformal()))
ax1, ax2 = axes
ax1.set_title('Field')
grid.reproject(crs.LambertConformal()).pcolor('gxx', ax=ax1)
#grid.reproject(crs.NorthPolarStereo()).points('.k', markersize=2, ax=ax1)
ax2.set_title('Difference (\%)')
#grid.reproject(crs.NorthPolarStereo()).pcolor('gxx_diff', ax=ax2)
ax2.gridlines()
ax2.set_xlim()
ax2.set_extent([60, 90, 330, 90], crs=crs.Geodetic())
fig

# %% [markdown]
# To load the data from the files, uncomment and run the following:

# %%
#tess_data = pd.read_csv(os.path.join(filedir, '30-deg-tesseroid-data.csv'), index_col=0)
#diff = pd.read_csv(os.path.join(filedir, '30-deg-difference.csv'), index_col=0)

# %% [markdown]
# ## Repeat these computations various sizes
#
# This is to check if the results are dependent on the size of the tesseroids.

# %%
sizes = [5, 2, 1]

# %% [markdown]
# Make the various model files and calculate their effects:

# %%
height = top + 1000
tess_files_per_size = []
for s in sizes:
    print('Calculating size {}'.format(s))
    mfile = make_model_file(s, top, bottom, density)
    tess_files_per_size.append([calc_tess_effect(mfile, height, s, r) for r in ratio])
# Out:
# Calculating size 5
# Calculating size 2
# Calculating size 1

# %% [markdown]
# I'll add the tesseroid effects to my `tess_data` object (remember, a `pandas.DataFrame` that is like a spreadsheet).

# %%
new_data = [load_tess_data(files, ratio, s) for s, files in zip(sizes, tess_files_per_size)]
tess_data = tess_data.append(pd.concat(new_data))
tess_data.head()
# Out:
#                                                     file          gx  \
# point
# 0      tesseroid_vs_spherical_shell_files/effect-mode...   -5.080438
# 1      tesseroid_vs_spherical_shell_files/effect-mode...   47.187352
# 2      tesseroid_vs_spherical_shell_files/effect-mode...  111.670908
# 3      tesseroid_vs_spherical_shell_files/effect-mode...  172.906610
# 4      tesseroid_vs_spherical_shell_files/effect-mode...   76.225435
#
#              gxx           gxy       gxz            gy        gyy  \
# point
# 0       2.740485 -2.120526e-14  0.012423  1.136868e-13  -0.206607
# 1       3.254847 -5.329071e-15 -0.119124 -2.842171e-13  -0.331153
# 2       4.083376 -2.042810e-14 -0.288925 -4.973799e-13   0.610316
# 3       1.426613 -4.707346e-14 -0.473062 -1.136868e-12   8.238928
# 4     -14.995095 -6.394885e-14 -0.226576 -1.932676e-12  32.672668
#
#                 gyz          gz        gzz           pot  ratio  size
# point
# 0     -4.857226e-16  110.584616  -2.533878  14057.411640      0    30
# 1      6.522560e-16  110.909484  -2.923694  14091.387903      0    30
# 2      1.193490e-15  112.199375  -4.693692  14222.035946      0    30
# 3      2.886580e-15  114.851910  -9.665542  14465.195711      0    30
# 4      5.218048e-15  118.001247 -17.677573  14713.512290      0    30

# %%
diff = calc_difference(tess_data, shell_data)
diff.head()
# Out:
#                gx        gxx           gxy       gxz            gy        gyy  \
# point
# 0        5.080438   3.091243  2.120526e-14  0.012423  1.136868e-13   0.144152
# 1       47.187352   3.605605  5.329071e-15  0.119124  2.842171e-13   0.019606
# 2      111.670908   4.434134  2.042810e-14  0.288925  4.973799e-13   0.961075
# 3      172.906610   1.777372  4.707346e-14  0.473062  1.136868e-12   8.589687
# 4       76.225435  14.644337  6.394885e-14  0.226576  1.932676e-12  33.023427
#
#                 gyz          gz        gzz         pot  size  ratio
# point
# 0      4.857226e-16  113.204014   3.235395  220.609550    30      0
# 1      6.522560e-16  112.879146   3.625211  186.633288    30      0
# 2      1.193490e-15  111.589255   5.395209   55.985245    30      0
# 3      2.886580e-15  108.936720  10.367058  187.174520    30      0
# 4      5.218048e-15  105.787383  18.379090  435.491100    30      0

# %%
max_diff = diff.groupby(['size', 'ratio']).max()
max_diff
# Out:
#                       gx          gxx          gxy          gxz           gy  \
# size ratio
# 1    0.0      677.950537   872.480495    24.925602  5218.136553     0.824880
#      0.5       19.865816   283.724706    12.430517    38.372466     1.299243
#      1.0        0.461321     8.463495     1.618280     2.061254     0.160758
#      1.5        0.088400     0.315925     0.140928     0.254481     0.015575
#      2.0        0.026243     0.126698     0.033689     0.076029     0.005190
#      2.5        0.007738     0.044740     0.011610     0.011842     0.002492
#      3.0        0.004209     0.012522     0.003971     0.011514     0.000841
#      3.5        0.001659     0.011771     0.002120     0.004172     0.000350
#      4.0        0.001251     0.006639     0.000939     0.002212     0.000249
#      4.5        0.000678     0.002920     0.000428     0.001603     0.000133
#      5.0        0.000439     0.002158     0.000259     0.000970     0.000057
#      5.5        0.000274     0.001309     0.000203     0.000473     0.000049
#      6.0        0.000208     0.000698     0.000091     0.000448     0.000027
#      6.5        0.000142     0.000621     0.000064     0.000280     0.000022
#      7.0        0.000111     0.000671     0.000056     0.000231     0.000012
#      7.5        0.000073     0.000470     0.000027     0.000228     0.000012
#      8.0        0.000061     0.000451     0.000020     0.000169     0.000009
# 2    0.0     1219.110858  2835.268878   889.213083  4315.161416    75.969980
#      0.5       34.876865   318.849616    88.247872   162.823738    10.960230
#      1.0        0.572350    11.286936     3.496050     4.510435     0.357228
#      1.5        0.109563     0.784646     0.288624     0.300645     0.043046
#      2.0        0.028883     0.107395     0.048245     0.051335     0.009390
#      2.5        0.008913     0.044903     0.011971     0.014403     0.004929
#      3.0        0.003964     0.017158     0.005414     0.012959     0.001428
#      3.5        0.001812     0.011759     0.002320     0.004458     0.001064
#      4.0        0.001255     0.006627     0.000960     0.002811     0.000340
#      4.5        0.000756     0.002484     0.000356     0.001400     0.000282
#      5.0        0.000420     0.002026     0.000317     0.000841     0.000099
#      5.5        0.000285     0.001155     0.000155     0.000523     0.000105
#      6.0        0.000236     0.000682     0.000099     0.000491     0.000041
# ...                  ...          ...          ...          ...          ...
# 5    2.0        0.029513     0.091948     0.049684     0.044230     0.013875
#      2.5        0.009220     0.048044     0.018332     0.020707     0.006286
#      3.0        0.004248     0.019881     0.003554     0.007432     0.001846
#      3.5        0.001792     0.009156     0.001795     0.002708     0.001140
#      4.0        0.001205     0.003779     0.000974     0.002397     0.000415
#      4.5        0.000679     0.002974     0.000569     0.001425     0.000237
#      5.0        0.000426     0.001974     0.000251     0.000787     0.000125
#      5.5        0.000292     0.001091     0.000192     0.000533     0.000081
#      6.0        0.000237     0.000705     0.000095     0.000422     0.000054
#      6.5        0.000152     0.000508     0.000099     0.000247     0.000037
#      7.0        0.000115     0.000312     0.000041     0.000188     0.000020
#      7.5        0.000095     0.000267     0.000030     0.000143     0.000022
#      8.0        0.000065     0.000179     0.000024     0.000126     0.000013
# 30   0.0    11095.326880  4629.793426  3030.511198   325.488084  4412.261681
#      0.5      113.615182   203.486129    70.203355    47.062307    81.442870
#      1.0        1.184469    14.740995     3.866946     3.845523     0.698832
#      1.5        0.114923     0.726540     0.380030     0.279439     0.094024
#      2.0        0.042898     0.113413     0.082160     0.068976     0.014692
#      2.5        0.008445     0.042375     0.016112     0.023419     0.004159
#      3.0        0.004803     0.027291     0.004151     0.010204     0.001495
#      3.5        0.001886     0.007556     0.002376     0.004958     0.000771
#      4.0        0.001310     0.007496     0.001781     0.003320     0.000401
#      4.5        0.000619     0.003153     0.000505     0.001104     0.000180
#      5.0        0.000387     0.001604     0.000351     0.001188     0.000124
#      5.5        0.000281     0.001292     0.000306     0.000507     0.000076
#      6.0        0.000210     0.001016     0.000135     0.000542     0.000051
#      6.5        0.000128     0.000558     0.000104     0.000281     0.000036
#      7.0        0.000105     0.000698     0.000066     0.000226     0.000025
#      7.5        0.000090     0.000357     0.000043     0.000195     0.000017
#      8.0        0.000059     0.000279     0.000047     0.000147     0.000016
#
#                     gyy         gyz          gz          gzz          pot
# size ratio
# 1    0.0     245.800475   25.376833  677.986990   785.537649    34.145287
#      0.5      64.388814   27.551457   99.543785   282.668270     6.633058
#      1.0       5.765227    5.673259    0.277084     3.899462     0.074862
#      1.5       0.702752    0.312757    0.148144     0.631848     0.022324
#      2.0       0.216188    0.086604    0.025392     0.212954     0.007386
#      2.5       0.069027    0.029420    0.015305     0.075300     0.002221
#      3.0       0.032935    0.008939    0.006213     0.039297     0.001321
#      3.5       0.017101    0.005474    0.004246     0.023544     0.000583
#      4.0       0.009539    0.002243    0.001953     0.013280     0.000492
#      4.5       0.004658    0.001548    0.001426     0.004963     0.000218
#      5.0       0.003489    0.000889    0.000869     0.005146     0.000200
#      5.5       0.001557    0.000425    0.000679     0.002265     0.000094
#      6.0       0.001364    0.000486    0.000465     0.001514     0.000092
#      6.5       0.000816    0.000222    0.000370     0.001091     0.000050
#      7.0       0.000671    0.000153    0.000268     0.001343     0.000046
#      7.5       0.000455    0.000107    0.000207     0.000909     0.000030
#      8.0       0.000451    0.000070    0.000154     0.000902     0.000029
# 2    0.0     969.185866  502.406350  592.536668  2348.336791    78.307645
#      0.5     333.683939  275.928140  105.797480   254.936431    14.799794
#      1.0      12.068699    4.714276    0.811234     4.246308     0.144939
#      1.5       0.808558    0.476592    0.228090     0.617714     0.049409
#      2.0       0.196600    0.094827    0.032144     0.188477     0.014379
#      2.5       0.061463    0.039454    0.019518     0.068162     0.004280
#      3.0       0.028677    0.008599    0.006649     0.033318     0.002516
#      3.5       0.015824    0.005292    0.005041     0.023519     0.001104
#      4.0       0.007346    0.003266    0.002137     0.013256     0.000951
#      4.5       0.003919    0.002102    0.001639     0.004801     0.000403
#      5.0       0.003517    0.000924    0.000955     0.004797     0.000376
#      5.5       0.001548    0.000572    0.000737     0.002286     0.000174
#      6.0       0.001173    0.000426    0.000482     0.001689     0.000175
# ...                 ...         ...         ...          ...          ...
# 5    2.0       0.164372    0.093814    0.033450     0.182448     0.035175
#      2.5       0.062135    0.024461    0.023479     0.057880     0.009953
#      3.0       0.027337    0.009029    0.006476     0.031913     0.005959
#      3.5       0.015045    0.006282    0.004719     0.012716     0.002551
#      4.0       0.007493    0.003393    0.002244     0.007751     0.002087
#      4.5       0.003862    0.001923    0.001818     0.005948     0.000858
#      5.0       0.002045    0.001013    0.000962     0.003057     0.000792
#      5.5       0.001365    0.000511    0.000760     0.001784     0.000367
#      6.0       0.000960    0.000377    0.000493     0.001575     0.000335
#      6.5       0.000664    0.000276    0.000380     0.000856     0.000184
#      7.0       0.000556    0.000163    0.000272     0.000643     0.000154
#      7.5       0.000290    0.000147    0.000214     0.000502     0.000103
#      8.0       0.000259    0.000093    0.000157     0.000358     0.000096
# 30   0.0    1711.272592  130.389153  361.782832  2918.520834  4328.250458
#      0.5     482.170746   45.336597  113.549427   326.943150   260.748575
#      1.0      11.624786    2.182199    0.644165     3.119782     2.389878
#      1.5       0.788297    0.305783    0.281056     0.498055     1.358251
#      2.0       0.167472    0.065274    0.035118     0.154040     0.086626
#      2.5       0.060576    0.012972    0.024220     0.083600     0.078116
#      3.0       0.024478    0.011345    0.007229     0.035686     0.018671
#      3.5       0.012203    0.006435    0.005393     0.011096     0.013664
#      4.0       0.008458    0.003492    0.002325     0.008523     0.004656
#      4.5       0.004097    0.001491    0.001753     0.004336     0.003599
#      5.0       0.002352    0.001180    0.001010     0.003072     0.001668
#      5.5       0.001402    0.000510    0.000784     0.001759     0.001436
#      6.0       0.001017    0.000525    0.000508     0.002032     0.000857
#      6.5       0.000615    0.000300    0.000420     0.001066     0.000668
#      7.0       0.000698    0.000201    0.000299     0.001395     0.000380
#      7.5       0.000357    0.000209    0.000220     0.000714     0.000314
#      8.0       0.000297    0.000139    0.000166     0.000558     0.000182
#
# [68 rows x 10 columns]

# %% [markdown]
# Since $g_x$ and $g_y$ and tensor the cross components are zero, I can't calculate the relative difference between the tesseroid model values and the shell values (which are zero). Instead, I'll calculate the difference relative to $g_z$ (for $g_x$ and $g_y$) and $g_{zz}$ (for $g_{xy}$, $g_{xz}$, and $g_{yz}$).

# %%
fig, subplots = plt.subplots(10, 2, figsize=(10, 25))
for f, axes in zip(['pot', 'gx', 'gy', 'gz', 'gxx', 'gxy', 'gxz', 'gyy', 'gyz', 'gzz'], subplots):
    for size in max_diff.index.levels[0]:
        d = max_diff[f].loc[size, :]
        ax1, ax2 = axes
        ax1.text(0.8, 0.8, f, fontsize=16, transform=ax1.transAxes)
        ax1.plot(ratio, d, '.-')
        ax1.set_yscale('log')
        ax1.grid(True)
        ax1.set_ylabel('Difference')
        ref = np.abs(shell_data[f])
        if f in ['gx', 'gy']:
            ref = np.abs(shell_data['gz'])            
        if f in ['gxy', 'gxz', 'gyz']:
            ref = np.abs(shell_data['gzz'])
        ax2.plot(ratio, 100*d/ref, '.-', label='${}^\circ$'.format(size))
        ax2.set_yscale('log')
        ax2.grid(True)
        ax2.set_ylabel('Difference (\%)')
        ax2.hlines(0.1, ratio.min(), ratio.max(), colors='r')
        ax2.set_xlim(ratio.min(), ratio.max())
    ax2.legend(loc='upper right', numpoints=1)
ax1.set_xlabel('Distance/size ratio')
ax2.set_xlabel('Distance/size ratio')
ax1, ax2 = subplots[0]
ax1.set_title('Absolute difference')
ax2.set_title('Realtive difference')
plt.tight_layout()
plt.show()

# %% [markdown]
# Save the tesseroid and difference `DataFrame`s to CSV so I can load them later.

# %%
tess_data.to_csv(os.path.join(filedir, 'tesseroid-data.csv'), sep=';')
diff.to_csv(os.path.join(filedir, 'difference.csv'), sep=';')

# %%
# Use these commands to read the data back in from the CSV files
tess_data = pd.read_csv(os.path.join(filedir, 'tesseroid-data.csv'), sep=';', index_col=0)
diff = pd.read_csv(os.path.join(filedir, 'difference.csv'), sep=';', index_col=0)
max_diff = diff.groupby(['size', 'ratio']).max()

# %% [markdown]
# Now I have to make the plots that will go into the paper. I'll plot only the relative difference.

# %%
#colors = [plt.cm.YlGn(c) for c in np.linspace(0, 1, 4)]
colors = "#8c510a #d8b365 #5ab4ac #01665e".split()
styles = ['-', '-', '-', '-']

fig, subplots = plt.subplots(4, 3, sharey='row', sharex='col')
fig.set_size_inches(9, 7)
axes = [subplots[0, 0]] + subplots.ravel()[3:].tolist()

for f, ax in zip(['pot', 'gx', 'gy', 'gz', 'gxx', 'gyy', 'gzz', 'gxy', 'gxz', 'gyz'], axes):
    for sty, c, size in zip(styles, colors, max_diff.index.levels[0]):
        d = max_diff[f].loc[size, :]
        title = f
        if f == 'pot':
            title = 'V'
        ax.text(0.9, 0.85, title, fontsize=11, 
                horizontalalignment='center', verticalalignment='center',
                bbox={'facecolor': '#f8f8f8', 
                      'edgecolor': '#9b9b9b',
                      'linewidth': 0.5, 'pad': 8}, 
                transform=ax.transAxes)
        ref = np.abs(shell_data[f])
        if f in ['gx', 'gy']:
            ref = np.abs(shell_data['gz'])            
        if f in ['gxy', 'gxz', 'gyz']:
            ref = np.abs(shell_data['gzz'])
        ax.plot(ratio, 100*d/ref, sty, label='${:.0f}^\circ$'.format(size), color=c)
        ax.set_yscale('log')
        ax.grid(True)
        ax.hlines(0.5, ratio.min(), ratio.max(), colors='k', linestyles='-', linewidth=1)
        ax.set_xlim(ratio.min(), ratio.max())
        
for ax in subplots[0, 1:]:
    ax.axison = False
    
ax = subplots[0, 0]
legend = ax.legend(numpoints=1, borderpad=1, title='Tesseroid size', ncol=2, bbox_to_anchor=(2.3, 0.8), 
                   fancybox=True, shadow=True)
rect = legend.get_frame()
rect.set_linewidth(0.0)

ax.set_ylim(1e-7, 1e4)
ax.set_yticks([1e-6, 1e-4, 1e-2, 1, 1e2])
for ax in subplots[1, :].ravel():
    ax.set_ylim(1e-6, 1e4)
    ax.set_yticks([1e-4, 1e-2, 1, 1e2])
for ax in subplots[2:, :].ravel():    
    ax.set_ylim(1e-3, 1e7)
    ax.set_yticks([1e-2, 1, 1e2, 1e4, 1e6])
    
for ax in subplots[-1, :]:
    ax.set_xticks(ax.get_xticks()[0:-1])
for ax in subplots[:, 0]:
    ax.minorticks_off()
    
for ax in subplots[:, 0]:
    ax.set_ylabel('Difference (\%)')
for ax in subplots[-1, :]:
    ax.set_xlabel('Distance/size ratio')
    
plt.subplots_adjust(hspace=0, wspace=0, top=0.97, bottom=0.08, left=0.1, right=0.99)
plt.savefig('../figs/tesseroid-x-shell.eps')
fig

# %% [markdown]
# ## References
# Grombein, T., K. Seitz, and B. Heck (2013), Optimized formulas for the gravitational field of a tesseroid, J Geod, 87(7), 645-660, doi:10.1007/s00190-013-0636-1.
